# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Historical_data_Population.csv")

# %%
df
# Out:
#     Unnamed: 0  Year  Population Yearly % Change  Yearly Change  \
# 0            0  2020  1380004385          0.99 %       13586631
# 1            1  2019  1366417754          1.02 %       13775474
# 2            2  2018  1352642280          1.04 %       13965495
# 3            3  2017  1338676785          1.07 %       14159536
# 4            4  2016  1324517249          1.10 %       14364846
# 5            5  2015  1310152403          1.20 %       15174247
# 6            6  2010  1234281170          1.47 %       17334249
# 7            7  2005  1147609927          1.67 %       18206876
# 8            8  2000  1056575549          1.85 %       18530592
# 9            9  1995   963922588          1.99 %       18128958
# 10          10  1990   873277798          2.17 %       17783558
# 11          11  1985   784360008          2.33 %       17081433
# 12          12  1980   698952844          2.32 %       15169989
# 13          13  1975   623102897          2.33 %       13582621
# 14          14  1970   555189792          2.15 %       11213294
# 15          15  1965   499123324          2.07 %        9715129
# 16          16  1960   450547679          1.91 %        8133417
# 17          17  1955   409880595          1.72 %        6711079
#
#     Migrants (net)  Median Age  Fertility Rate  Density (P/Km²) Urban Pop %  \
# 0          -532687        28.4            2.24              464      35.0 %
# 1          -532687        27.1            2.36              460      34.5 %
# 2          -532687        27.1            2.36              455      34.1 %
# 3          -532687        27.1            2.36              450      33.6 %
# 4          -532687        27.1            2.36              445      33.2 %
# 5          -470015        26.8            2.40              441      32.7 %
# 6          -531169        25.1            2.80              415      30.8 %
# 7          -377797        23.8            3.14              386      29.1 %
# 8          -136514        22.7            3.48              355      27.6 %
# 9          -110590        21.8            3.83              324      26.5 %
# 10            9030        21.1            4.27              294      25.5 %
# 11          115942        20.6            4.68              264      24.3 %
# 12          222247        20.2            4.97              235      23.0 %
# 13          421208        19.7            5.41              210      21.3 %
# 14          -68569        19.3            5.72              187      19.7 %
# 15          -17078        19.6            5.89              168      18.7 %
# 16          -30805        20.2            5.90              152      17.9 %
# 17          -21140        20.7            5.90              138      17.6 %
#
#     Urban Population Country's Share of World Pop  World Population  \
# 0          483098640                      17.70 %        7794798739
# 1          471828295                      17.71 %        7713468100
# 2          460779764                      17.73 %        7631091040
# 3          449963381                      17.74 %        7547858925
# 4          439391699                      17.75 %        7464022049
# 5          429069459                      17.75 %        7379797139
# 6          380744554                      17.74 %        6956823603
# 7          334479406                      17.54 %        6541907027
# 8          291350282                      17.20 %        6143493823
# 9          255558824                      16.78 %        5744212979
# 10         222296728                      16.39 %        5327231061
# 11         190321782                      16.10 %        4870921740
# 12         160941941                      15.68 %        4458003514
# 13         132533810                      15.27 %        4079480606
# 14         109388950                      15.00 %        3700437046
# 15          93493844                      14.95 %        3339583597
# 16          80565723                      14.85 %        3034949748
# 17          71958495                      14.78 %        2773019936
#
#     IndiaGlobal Rank
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
# 5                  2
# 6                  2
# 7                  2
# 8                  2
# 9                  2
# 10                 2
# 11                 2
# 12                 2
# 13                 2
# 14                 2
# 15                 2
# 16                 2
# 17                 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    18 non-null     int64
#  1   Year                          18 non-null     int64
#  2   Population                    18 non-null     int64
#  3   Yearly % Change               18 non-null     object
#  4   Yearly Change                 18 non-null     int64
#  5   Migrants (net)                18 non-null     int64
#  6   Median Age                    18 non-null     float64
#  7   Fertility Rate                18 non-null     float64
#  8   Density (P/Km²)               18 non-null     int64
#  9   Urban Pop %                   18 non-null     object
#  10  Urban Population              18 non-null     int64
#  11  Country's Share of World Pop  18 non-null     object
#  12  World Population              18 non-null     int64
#  13  IndiaGlobal Rank              18 non-null     int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0         Year    Population  Yearly Change  Migrants (net)  \
# count   18.000000    18.000000  1.800000e+01   1.800000e+01       18.000000
# mean     8.500000  1994.166667  9.649575e+08   1.425652e+07  -203260.277778
# std      5.338539    22.350813  3.574762e+08   3.480954e+06   306640.859173
# min      0.000000  1955.000000  4.098806e+08   6.711079e+06  -532687.000000
# 25%      4.250000  1976.250000  6.420654e+08   1.358362e+07  -532307.500000
# 50%      8.500000  1997.500000  1.010249e+09   1.426219e+07  -123552.000000
# 75%     12.750000  2015.750000  1.320926e+09   1.727104e+07   -18093.500000
# max     17.000000  2020.000000  1.380004e+09   1.853059e+07   421208.000000
#
#        Median Age  Fertility Rate  Density (P/Km²)  Urban Population  \
# count   18.000000       18.000000        18.000000      1.800000e+01
# mean    23.244444        3.892778       324.611111      2.809870e+08
# std      3.279387        1.453247       120.108842      1.524912e+08
# min     19.300000        2.240000       138.000000      7.195850e+07
# 25%     20.300000        2.370000       216.250000      1.396358e+08
# 50%     22.250000        3.655000       339.500000      2.734546e+08
# 75%     27.025000        5.300000       444.000000      4.368111e+08
# max     28.400000        5.900000       464.000000      4.830986e+08
#
#        World Population  IndiaGlobal Rank
# count      1.800000e+01              18.0
# mean       5.694506e+09               2.0
# std        1.786229e+09               0.0
# min        2.773020e+09               2.0
# 25%        4.174111e+09               2.0
# 50%        5.943853e+09               2.0
# 75%        7.442966e+09               2.0
# max        7.794799e+09               2.0

# %%
plt.figure(figsize=(12,6))
plt.title("Population over the year")
sns.barplot(x=df['Year'], y=df['Population']);

# %%
df.plot(x="Year", y=["Population", "World Population"], kind="bar",figsize=(12, 6),title = "compare with World population")
# Out:
# <AxesSubplot:title={'center':'compare with World population'}, xlabel='Year'>

# %%
plt.figure(figsize=(12,6))
plt.title("Population over the year")
sns.lineplot(x=df['Year'], y=df["Country's Share of World Pop"]);

# %%
plt.figure(figsize=(12,6))
plt.title("Density over the year")
sns.barplot(x=df['Year'], y=df['Density (P/Km²)']);

# %%
plt.figure(figsize=(12,6))

sns.barplot(x=df['Year'], y=df['Yearly Change']);

# %%
plt.figure(figsize=(12,6))

sns.lineplot(x=df['Year'], y=df['Yearly % Change']);

# %%
plt.figure(figsize=(12,7))

sns.lineplot(x=df['Year'], y=df['Urban Pop %']);
